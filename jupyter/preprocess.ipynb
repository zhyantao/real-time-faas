# %%
from models.utils.dag import *
from models.utils.dataset import *

# %%
sample_machines()
# Out:
# Dataset container_usage.csv is already selected.

# %%
sample_jobs()
# Out:
# Dataset (batch_task.csv & batch_instance.csv) is already selected.

# %%
get_topological_order()
# Out:
# Jobs' topological order has been obtained.

# %%
df_batch_task = pd.read_csv("E:/Workshop/real-time-faas/dataset/selected_batch_task.csv")
df_rows = df_batch_task.shape[0]

# %%
# 绘制 selected_batch_task.csv 中包含的所有图片
idx = 0
while idx < df_rows:
    job, idx = get_one_job(df_batch_task, idx)
    show(job)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_52012\2175429663.py in <module>
#       3 while idx < df_rows:
#       4     job, idx = get_one_job(df_batch_task, idx)
# ----> 5     show(job)
#
# E:\Workshop\real-time-faas\models\utils\dag.py in show(job, job_name)
#      42
#      43     # 展示图像
# ---> 44     pos = nx.nx_agraph.graphviz_layout(G, prog='dot')
#      45     edge_labels = nx.get_edge_attributes(G, "weight")
#      46     nx.draw(G, pos, font_color='whitesmoke', with_labels=True)
#
# D:\ProgramData\miniconda3\envs\python37\lib\site-packages\networkx\drawing\nx_agraph.py in graphviz_layout(G, prog, root, args)
#     237     This is a wrapper for pygraphviz_layout.
#     238     """
# --> 239     return pygraphviz_layout(G, prog=prog, root=root, args=args)
#     240
#     241
#
# D:\ProgramData\miniconda3\envs\python37\lib\site-packages\networkx\drawing\nx_agraph.py in pygraphviz_layout(G, prog, root, args)
#     285         args += f"-Groot={root}"
#     286     A = to_agraph(G)
# --> 287     A.layout(prog=prog, args=args)
#     288     node_pos = {}
#     289     for n in G:
#
# D:\ProgramData\miniconda3\envs\python37\lib\site-packages\pygraphviz\agraph.py in layout(self, prog, args)
#    1465         output_fmt = "dot"
#    1466         data = self._run_prog(prog, " ".join([args, "-T", output_fmt]))
# -> 1467         self.from_string(data)
#    1468         self.has_layout = True
#    1469         return
#
# D:\ProgramData\miniconda3\envs\python37\lib\site-packages\pygraphviz\agraph.py in from_string(self, string)
#    1312         from tempfile import TemporaryFile
#    1313
# -> 1314         fh = TemporaryFile()
#    1315         fh.write(string.encode(self.encoding))
#    1316         fh.seek(0)
#
# D:\ProgramData\miniconda3\envs\python37\lib\tempfile.py in NamedTemporaryFile(mode, buffering, encoding, newline, suffix, prefix, dir, delete)
#     545         flags |= _os.O_TEMPORARY
#     546
# --> 547     (fd, name) = _mkstemp_inner(dir, prefix, suffix, flags, output_type)
#     548     try:
#     549         file = _io.open(fd, mode, buffering=buffering,
#
# D:\ProgramData\miniconda3\envs\python37\lib\tempfile.py in _mkstemp_inner(dir, pre, suf, flags, output_type)
#     256         file = _os.path.join(dir, pre + name + suf)
#     257         try:
# --> 258             fd = _os.open(file, flags, 0o600)
#     259         except FileExistsError:
#     260             continue    # try again
#
# KeyboardInterrupt:

# %%
# 合并 job1 和 job2
job1, idx = get_one_job(df_batch_task)
job2, _ = get_one_job(df_batch_task, idx)

# show
show(job1)
show(job2)

# merge job1 和 job2
job = merge(job1, job2)
job1_name = job1['job_name'].loc[job1.index[0]]
job2_name = job2['job_name'].loc[job2.index[0]]
show(job, job1_name + "_" + job2_name)
