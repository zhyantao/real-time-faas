# %%
from models.utils.dag import *
from models.utils.dataset import *

# %%
sample_machines()
# Out:
# Dataset container_usage.csv is already selected.

# %%
sample_jobs()
# Out:
# Dataset (batch_task.csv & batch_instance.csv) is already selected.

# %%
get_topological_order()
# Out:
# Jobs' topological order has been obtained.

# %%
df_batch_task = pd.read_csv("E:/Workshop/real-time-faas/dataset/selected_batch_task.csv")
df_rows = df_batch_task.shape[0]

# %%
# 绘制 selected_batch_task.csv 中包含的所有图片
idx = 0
while idx < df_rows:
    job, idx = get_one_job(df_batch_task, idx)
    show(job)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 5
#       3 while idx < df_rows:
#       4     job, idx = get_one_job(df_batch_task, idx)
# ----> 5     show(job)
#
# File E:\Workshop\real-time-faas\models\utils\dag.py:44, in show(job, job_name)
#      41             i += 1
#      43 # 展示图像
# ---> 44 pos = nx.nx_agraph.graphviz_layout(G, prog='dot')
#      45 edge_labels = nx.get_edge_attributes(G, "weight")
#      46 nx.draw(G, pos, font_color='whitesmoke', with_labels=True)
#
# File D:\Program Files\Python39\lib\site-packages\networkx\drawing\nx_agraph.py:251, in graphviz_layout(G, prog, root, args)
#     220 def graphviz_layout(G, prog="neato", root=None, args=""):
#     221     """Create node positions for G using Graphviz.
#     222
#     223     Parameters
#    (...)
#     249     see https://gitlab.com/graphviz/graphviz/-/issues/1767 for more info.
#     250     """
# --> 251     return pygraphviz_layout(G, prog=prog, root=root, args=args)
#
# File D:\Program Files\Python39\lib\site-packages\networkx\drawing\nx_agraph.py:303, in pygraphviz_layout(G, prog, root, args)
#     301     args += f"-Groot={root}"
#     302 A = to_agraph(G)
# --> 303 A.layout(prog=prog, args=args)
#     304 node_pos = {}
#     305 for n in G:
#
# File D:\Program Files\Python39\lib\site-packages\pygraphviz\agraph.py:1481, in AGraph.layout(self, prog, args)
#    1464 """Assign positions to nodes in graph.
#    1465
#    1466 Optional prog=['neato'|'dot'|'twopi'|'circo'|'fdp'|'nop']
#    (...)
#    1478
#    1479 """
#    1480 output_fmt = "dot"
# -> 1481 data = self._run_prog(prog, " ".join([args, "-T", output_fmt]))
#    1482 self.from_string(data)
#    1483 self.has_layout = True
#
# File D:\Program Files\Python39\lib\site-packages\pygraphviz\agraph.py:1398, in AGraph._run_prog(self, prog, args)
#    1395 child_stdin.close()
#    1397 for t in threads:
# -> 1398     t.join()
#    1399 p.wait()
#    1401 if not data:
#
# File D:\Program Files\Python39\lib\threading.py:1060, in Thread.join(self, timeout)
#    1057     raise RuntimeError("cannot join current thread")
#    1059 if timeout is None:
# -> 1060     self._wait_for_tstate_lock()
#    1061 else:
#    1062     # the behavior of a negative timeout isn't documented, but
#    1063     # historically .join(timeout=x) for x<0 has acted as if timeout=0
#    1064     self._wait_for_tstate_lock(timeout=max(timeout, 0))
#
# File D:\Program Files\Python39\lib\threading.py:1080, in Thread._wait_for_tstate_lock(self, block, timeout)
#    1077     return
#    1079 try:
# -> 1080     if lock.acquire(block, timeout):
#    1081         lock.release()
#    1082         self._stop()
#
# KeyboardInterrupt:

# %%
# 合并 job1 和 job2
job1, idx = get_one_job(df_batch_task)
job2, _ = get_one_job(df_batch_task, idx)

# show
show(job1)
show(job2)

# merge job1 和 job2
job = merge(job1, job2)
job1_name = job1['job_name'].loc[job1.index[0]]
job2_name = job2['job_name'].loc[job2.index[0]]
show(job, job1_name + "_" + job2_name)
