# %%
from models.autoscaler.neural_network import model_parallel_test

# %%
if __name__ == '__main__':
    # single_cuda_test()
    # multi_cuda_test()
    model_parallel_test()
# Out:
# running at device cuda
# TRAIN[0000000001] Time:     4.3492s
# TRAIN[0000000002] Time:     1.0048s
# TRAIN[0000000003] Time:     0.8104s
# TRAIN[0000000004] Time:     0.1563s
# TRAIN[0000000005] Time:     0.6261s
# TRAIN[0000000006] Time:     0.6122s
# TRAIN[0000000007] Time:     0.6116s
# TRAIN[0000000008] Time:     0.6127s
# TRAIN[0000000009] Time:     0.6114s
# TRAIN[0000000010] Time:     0.6117s
# TRAIN[0000000011] Time:     0.6133s
# TRAIN[0000000012] Time:     0.6146s
# TRAIN[0000000013] Time:     0.6146s
# TRAIN[0000000014] Time:     0.6158s
# TRAIN[0000000015] Time:     0.6147s
# TRAIN[0000000016] Time:     0.6155s
# TRAIN[0000000017] Time:     0.6161s
# TRAIN[0000000018] Time:     0.6168s
# TRAIN[0000000019] Time:     0.6194s
# TRAIN[0000000020] Time:     0.6159s
# TRAIN[0000000021] Time:     0.6181s
# TRAIN[0000000022] Time:     0.6181s
# TRAIN[0000000023] Time:     0.6192s
# TRAIN[0000000024] Time:     0.6203s
# TRAIN[0000000025] Time:     0.6189s
# ...
