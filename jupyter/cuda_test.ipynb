# %%
from models.autoscaler.neural_network import model_parallel_test

# %%
if __name__ == '__main__':
    # single_cuda_test()
    # multi_cuda_test()
    model_parallel_test()
# Out:
# running at device cuda
# TRAIN[0000000001] Time:     4.6510s
# TRAIN[0000000002] Time:     1.1072s
# TRAIN[0000000003] Time:     0.8862s
# TRAIN[0000000004] Time:     0.1850s
# TRAIN[0000000005] Time:     0.6651s
# TRAIN[0000000006] Time:     0.6681s
# TRAIN[0000000007] Time:     0.6661s
# TRAIN[0000000008] Time:     0.6662s
# TRAIN[0000000009] Time:     0.6681s
# TRAIN[0000000010] Time:     0.6702s
# TRAIN[0000000011] Time:     0.6712s
# TRAIN[0000000012] Time:     0.6712s
# TRAIN[0000000013] Time:     0.6701s
# TRAIN[0000000014] Time:     0.6722s
# TRAIN[0000000015] Time:     0.6722s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 4
#       1 if __name__ == '__main__':
#       2     # single_cuda_test()
#       3     # multi_cuda_test()
# ----> 4     model_parallel_test()
#
# ...
