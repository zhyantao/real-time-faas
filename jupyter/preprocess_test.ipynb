# %%
from models.utils.dag import *
from models.utils.preprocessing import *

# %%
sample_jobs()
# Out:
# Dataset (batch_task.csv & batch_instance.csv) is already selected.

# %%
get_topological_order()
# Out:
# Jobs' topological order has been obtained.

# %%
df_batch_task = pd.read_csv("E:/Workshop/real-time-faas/dataset/selected_batch_task.csv")
df_rows = df_batch_task.shape[0]

# %%
# 绘制 selected_batch_task.csv 中包含的所有图片
idx = 0
while idx < df_rows:
    job_name = df_batch_task.loc[idx, 'job_name']
    task_nums = 0
    while (idx + task_nums < df_rows) and (job_name == df_batch_task.loc[idx + task_nums, 'job_name']):
        task_nums += 1
    job = df_batch_task.loc[idx: idx + task_nums - 1].copy()
    show(job)
    idx += task_nums

# %%
# TODO: DAG merge 函数未能找到合适的合并数据
idx, task_nums = 0, 0

# job1
job1_name = df_batch_task.loc[idx, 'job_name']
while (idx + task_nums < df_rows) and (job1_name == df_batch_task.loc[idx + task_nums, 'job_name']):
    task_nums += 1
job1 = df_batch_task.loc[idx: idx + task_nums - 1].copy()
idx += task_nums

# job2
job2_name = df_batch_task.loc[idx, 'job_name']
while (idx + task_nums < df_rows) and (job2_name == df_batch_task.loc[idx + task_nums, 'job_name']):
    task_nums += 1
job2 = df_batch_task.loc[idx: idx + task_nums - 1].copy()
idx += task_nums

# show
show(job1)
show(job2)

# merge job1 和 job2
job = merge(job1, job2)
show(job, job1_name + "_" + job2_name)
