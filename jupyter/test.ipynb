# %%
from models.utils.figure import RuntimeFigure

runtime_figure = RuntimeFigure()
runtime_figure.visual()
# Out:
# usage: ipykernel_launcher.py [-h]
#                              [--selected_container_usage_path SELECTED_CONTAINER_USAGE_PATH]
#                              [--container_usage_path CONTAINER_USAGE_PATH]
#                              [--total_machines TOTAL_MACHINES]
#                              [--total_jobs TOTAL_JOBS]
#                              [--batch_task_path BATCH_TASK_PATH]
#                              [--selected_batch_task_path SELECTED_BATCH_TASK_PATH]
#                              [--batch_task_topological_order_path BATCH_TASK_TOPOLOGICAL_ORDER_PATH]
#                              [--batch_instance_path BATCH_INSTANCE_PATH]
#                              [--selected_batch_instance_path SELECTED_BATCH_INSTANCE_PATH]
#                              [--batch_instance_topological_order_path BATCH_INSTANCE_TOPOLOGICAL_ORDER_PATH]
#                              [--result_saving_path RESULT_SAVING_PATH]
#                              [--max_value MAX_VALUE]
# ...
